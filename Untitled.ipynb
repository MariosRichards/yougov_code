# %% [raw]
# conda create --name yougov numpy scipy matplotlib jupyter
# activate yougov
#
# https://d25d2506sfb94s.cloudfront.net/cumulus_uploads/document/a8ttjt0lgq/ElectionDataResults_160923_FinalCall.pdf
#
# Able2Extract pdfs -> excel

# %%
# Columns
Leadership_Vote_2015 = [ "Jeremy Corbyn", "Yvette Cooper", "Andy Burnham", "Liz Kendall", "Did not vote" ]
Membership_Length    = [ "Pre 2015 GE", "During 2015 Leadership Election", "After JC Elected" ]
EU_Ref_Vote          = [ "Remain", "Leave" ]
GE_Vote_2015         = [ "Labour", "Not Labour" ]
Gender               = [ "Male", "Female" ]
Age                  = [ "18-24", "25-39", "40-59", "60+" ]
Social_Grade         = [ "ABC1", "C2DE" ]
Region               = [ "London", "Rest of South", "Midlands / Wales",	"North", "Scotland" ]

yougov_categories = [Leadership_Vote_2015, Membership_Length, EU_Ref_Vote, GE_Vote_2015, Gender, Age, Social_Grade, Region]

# %% [raw]
# Rows
# Weighted Sample
# Did you vote?: ["I have voted" "I have not voted"]
# Who did you vote for?: ["Owen Smith" "Jeremy Corbyn" "Don’t know"]

# %% [raw]
# Goals
# (1) Infer weightings
# (2) Infer approximate raw numbers
# (3) Statistical test (discrete)
#
# Steps
# (1) Load datasets
# (2) Merge into one clean dataset
# (3) Get weightings by sub-category

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
table1 = pd.read_csv("..\yougov_data\yougov_data_1.csv",encoding = 'iso-8859-1')

table2 = pd.read_csv("..\yougov_data\yougov_data_2.csv",encoding = 'iso-8859-1')

# %%
full_table = pd.concat([table1, table2.drop("Total",axis=1).drop('Unnamed: 0',axis=1)],axis=1)

# %%
full_table.columns
# Out:
# Index(['Unnamed: 0', 'Total', 'Jeremy Corbyn', 'Yvette Cooper', 'Andy Burnham',
#        'Liz Kendall', 'Did not vote', 'Pre 2015 GE',
#        'During 2015 Leadership Election', 'After JC Elected', 'Remain',
#        'Leave', 'Labour', 'Not Labour', 'Male', 'Female', '18-24', '25-39',
#        '40-59', '60+', 'ABC1', 'C2DE', 'London', 'Rest of South',
#        'Midlands / Wales', 'North', 'Scotland', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15'],
#       dtype='object')

# %%
full_table
# Out:
#           Unnamed: 0  Total  Jeremy Corbyn  Yvette Cooper  Andy Burnham  \
# 0    Weighted Sample   1019            523            179           161
# 1  Unweighted Sample   1019            549            167           152
# 2       I have voted     97             97             98            94
# 3   I have not voted      3              3              2             6
# 4         Owen Smith     41             12             89            75
# 5      Jeremy Corbyn     59             87             10            25
# 6         Dont know      1              1              2             0
#
#    Liz Kendall  Did not vote  Pre 2015 GE  During 2015 Leadership Election  \
# 0           53            95          490                              293
# 1           45            97          491                              301
# 2           95            96           96                               96
# 3            5             4            4                                4
# 4           98            19           63                               25
# 5            2            79           37                               74
# 6            0             2            1                                0
#
#    After JC Elected     ...       ABC1  C2DE  London  Rest of South  \
# 0               236     ...        690   328     219            298
# 1               227     ...        768   250     157            333
# 2                99     ...         96    98      93             97
# 3                 1     ...          4     2       7              3
# 4                15     ...         42    37      47             40
# 5                83     ...         57    62      53             59
# 6                 1     ...          1     0       0              0
#
#    Midlands / Wales  North  Scotland  Unnamed: 13  Unnamed: 14  Unnamed: 15
# 0               180    271        51          NaN          NaN          NaN
# 1               185    290        53          NaN          NaN          NaN
# 2                97     98        98          NaN          NaN          NaN
# 3                 3      2         2          NaN          NaN          NaN
# 4                37     35        58          NaN          NaN          NaN
# 5                61     64        40          NaN          NaN          NaN
# 6                 2      1         3          NaN          NaN          NaN
#
# [7 rows x 30 columns]

# %%
ft = full_table.set_index( full_table.iloc[:,0].values ).drop("Unnamed: 0",axis=1)
ft
# Out:
#                    Total  Jeremy Corbyn  Yvette Cooper  Andy Burnham  \
# Weighted Sample     1019            523            179           161
# Unweighted Sample   1019            549            167           152
# I have voted          97             97             98            94
# I have not voted       3              3              2             6
# Owen Smith            41             12             89            75
# Jeremy Corbyn         59             87             10            25
# Dont know             1              1              2             0
#
#                    Liz Kendall  Did not vote  Pre 2015 GE  \
# Weighted Sample             53            95          490
# Unweighted Sample           45            97          491
# I have voted                95            96           96
# I have not voted             5             4            4
# Owen Smith                  98            19           63
# Jeremy Corbyn                2            79           37
# Dont know                   0             2            1
#
#                    During 2015 Leadership Election  After JC Elected  Remain  \
# Weighted Sample                                293               236     917
# Unweighted Sample                              301               227     915
# I have voted                                    96                99      97
# I have not voted                                 4                 1       3
# Owen Smith                                      25                15      43
# Jeremy Corbyn                                   74                83      57
# Dont know                                       0                 1       1
#
#                       ...       ABC1  C2DE  London  Rest of South  \
# Weighted Sample       ...        690   328     219            298
# Unweighted Sample     ...        768   250     157            333
# I have voted          ...         96    98      93             97
# I have not voted      ...          4     2       7              3
# Owen Smith            ...         42    37      47             40
# Jeremy Corbyn         ...         57    62      53             59
# Dont know            ...          1     0       0              0
#
#                    Midlands / Wales  North  Scotland  Unnamed: 13  \
# Weighted Sample                 180    271        51          NaN
# Unweighted Sample               185    290        53          NaN
# I have voted                     97     98        98          NaN
# I have not voted                  3      2         2          NaN
# Owen Smith                       37     35        58          NaN
# Jeremy Corbyn                    61     64        40          NaN
# Dont know                        2      1         3          NaN
#
#                    Unnamed: 14  Unnamed: 15
# Weighted Sample            NaN          NaN
# Unweighted Sample          NaN          NaN
# I have voted               NaN          NaN
# I have not voted           NaN          NaN
# Owen Smith                 NaN          NaN
# Jeremy Corbyn              NaN          NaN
# Dont know                 NaN          NaN
#
# [7 rows x 29 columns]

# %%
full_table.iloc[:,0].values
# Out:
# array(['Weighted Sample', 'Unweighted Sample', 'I have voted',
#        'I have not voted', 'Owen Smith', 'Jeremy Corbyn', 'Don\x92t know'], dtype=object)

# %%
ft
# Out:
#                    Total  Jeremy Corbyn  Yvette Cooper  Andy Burnham  \
# Weighted Sample     1019            523            179           161
# Unweighted Sample   1019            549            167           152
# I have voted          97             97             98            94
# I have not voted       3              3              2             6
# Owen Smith            41             12             89            75
# Jeremy Corbyn         59             87             10            25
# Dont know             1              1              2             0
#
#                    Liz Kendall  Did not vote  Pre 2015 GE  \
# Weighted Sample             53            95          490
# Unweighted Sample           45            97          491
# I have voted                95            96           96
# I have not voted             5             4            4
# Owen Smith                  98            19           63
# Jeremy Corbyn                2            79           37
# Dont know                   0             2            1
#
#                    During 2015 Leadership Election  After JC Elected  Remain  \
# Weighted Sample                                293               236     917
# Unweighted Sample                              301               227     915
# I have voted                                    96                99      97
# I have not voted                                 4                 1       3
# Owen Smith                                      25                15      43
# Jeremy Corbyn                                   74                83      57
# Dont know                                       0                 1       1
#
#                      ...     25-39  40-59  60+  ABC1  C2DE  London  \
# Weighted Sample      ...       269    367  267   690   328     219
# Unweighted Sample    ...       243    412  309   768   250     157
# I have voted         ...        98     98   95    96    98      93
# I have not voted     ...         2      2    5     4     2       7
# Owen Smith           ...        36     37   44    42    37      47
# Jeremy Corbyn        ...        63     62   55    57    62      53
# Dont know           ...         0      1    1     1     0       0
#
#                    Rest of South  Midlands / Wales  North  Scotland
# Weighted Sample              298               180    271        51
# Unweighted Sample            333               185    290        53
# I have voted                  97                97     98        98
# I have not voted               3                 3      2         2
# Owen Smith                    40                37     35        58
# Jeremy Corbyn                 59                61     64        40
# Dont know                     0                 2      1         3
#
# [7 rows x 26 columns]

# %%
ft.index[0]
# Out:
# 'Weighted Sample'

# %%
# weightings (to make the sample look like the uk electorate)
weightings  = ft.loc[ ft.index[0] ] / ft.loc[ ft.index[1] ]

# %%
weightings
# Out:
# Total                              1.000000
# Jeremy Corbyn                      0.952641
# Yvette Cooper                      1.071856
# Andy Burnham                       1.059211
# Liz Kendall                        1.177778
# Did not vote                       0.979381
# Pre 2015 GE                        0.997963
# During 2015 Leadership Election    0.973422
# After JC Elected                   1.039648
# Remain                             1.002186
# Leave                              0.978947
# Labour                             0.980723
# Not Labour                         1.084656
# Male                               0.962193
# Female                             1.040816
# 18-24                              2.109091
# 25-39                              1.106996
# 40-59                              0.890777
# 60+                                0.864078
# ABC1                               0.898438
# C2DE                               1.312000
# London                             1.394904
# Rest of South                      0.894895
# Midlands / Wales                   0.972973
# North                              0.934483
# Scotland                           0.962264
# dtype: float64

# %%
ft.loc[ ft.index[2:] ]
# Out:
#                   Total  Jeremy Corbyn  Yvette Cooper  Andy Burnham  \
# I have voted         97             97             98            94
# I have not voted      3              3              2             6
# Owen Smith           41             12             89            75
# Jeremy Corbyn        59             87             10            25
# Dont know            1              1              2             0
#
#                   Liz Kendall  Did not vote  Pre 2015 GE  \
# I have voted               95            96           96
# I have not voted            5             4            4
# Owen Smith                 98            19           63
# Jeremy Corbyn               2            79           37
# Dont know                  0             2            1
#
#                   During 2015 Leadership Election  After JC Elected  Remain  \
# I have voted                                   96                99      97
# I have not voted                                4                 1       3
# Owen Smith                                     25                15      43
# Jeremy Corbyn                                  74                83      57
# Dont know                                      0                 1       1
#
#                     ...     25-39  40-59  60+  ABC1  C2DE  London  \
# I have voted        ...        98     98   95    96    98      93
# I have not voted    ...         2      2    5     4     2       7
# Owen Smith          ...        36     37   44    42    37      47
# Jeremy Corbyn       ...        63     62   55    57    62      53
# Dont know          ...         0      1    1     1     0       0
#
#                   Rest of South  Midlands / Wales  North  Scotland
# I have voted                 97                97     98        98
# I have not voted              3                 3      2         2
# Owen Smith                   40                37     35        58
# Jeremy Corbyn                59                61     64        40
# Dont know                    0                 2      1         3
#
# [5 rows x 26 columns]

# %%
raw = ft.loc[ ft.index[2:] ] * ft.loc[ ft.index[0] ]/100

# %%
( ft.loc[ ft.index[4:] ]/100 ) *
# Out:
#                Total  Jeremy Corbyn  Yvette Cooper  Andy Burnham  Liz Kendall  \
# Owen Smith      0.41           0.12           0.89          0.75         0.98
# Jeremy Corbyn   0.59           0.87           0.10          0.25         0.02
# Dont know      0.01           0.01           0.02          0.00         0.00
#
#                Did not vote  Pre 2015 GE  During 2015 Leadership Election  \
# Owen Smith             0.19         0.63                             0.25
# Jeremy Corbyn          0.79         0.37                             0.74
# Dont know             0.02         0.01                             0.00
#
#                After JC Elected  Remain     ...       ABC1  C2DE  London  \
# Owen Smith                 0.15    0.43     ...       0.42  0.37    0.47
# Jeremy Corbyn              0.83    0.57     ...       0.57  0.62    0.53
# Dont know                 0.01    0.01     ...       0.01  0.00    0.00
#
#                Rest of South  Midlands / Wales  North  Scotland  Unnamed: 13  \
# Owen Smith              0.40              0.37   0.35      0.58          NaN
# Jeremy Corbyn           0.59              0.61   0.64      0.40          NaN
# Dont know              0.00              0.02   0.01      0.03          NaN
#
#                Unnamed: 14  Unnamed: 15
# Owen Smith             NaN          NaN
# Jeremy Corbyn          NaN          NaN
# Dont know             NaN          NaN
#
# [3 rows x 29 columns]

# %%
532.0 + 165.0 + 143.0 + 43.0 +  94.0
# Out:
# 977.0

# %%
# Out:
# Total                              998.3143
# Jeremy Corbyn                      532.5300
# Yvette Cooper                      165.2966
# Andy Burnham                       142.8800
# Liz Kendall                         42.7500
# Did not vote                        93.1200
# Pre 2015 GE                        476.0736
# During 2015 Leadership Election    286.0704
# After JC Elected                   222.4827
# Remain                             896.4255
# Leave                               89.3000
# Labour                             805.1000
# Not Labour                         179.5500
# Male                               507.8400
# Female                             475.3000
# 18-24                               51.1500
# 25-39                              235.7586
# 40-59                              403.7600
# 60+                                293.5500
# ABC1                               737.2800
# C2DE                               242.5500
# London                             146.0100
# Rest of South                      319.7799
# Midlands / Wales                   179.4500
# North                              284.2000
# Scotland                            52.4594
# Unnamed: 13                             NaN
# Unnamed: 14                             NaN
# Unnamed: 15                             NaN
# dtype: float64

# %%
raw
# Out:
#                   Total  Jeremy Corbyn  Yvette Cooper  Andy Burnham  \
# Owen Smith     405.2563        63.9036       145.6574        107.16
# Jeremy Corbyn  583.1737       463.3011        16.3660         35.72
# Dont know       9.8843         5.3253         3.2732          0.00
#
#                Liz Kendall  Did not vote  Pre 2015 GE  \
# Owen Smith          41.895       17.6928     296.9568
# Jeremy Corbyn        0.855       73.5648     174.4032
# Dont know           0.000        1.8624       4.7136
#
#                During 2015 Leadership Election  After JC Elected    Remain  \
# Owen Smith                             72.2400           33.7095  381.6465
# Jeremy Corbyn                         213.8304          186.5259  505.9035
# Dont know                              0.0000            2.2473    8.8755
#
#                   ...           ABC1    C2DE   London  Rest of South  \
# Owen Smith        ...       309.6576   90.65  68.6247       129.2040
# Jeremy Corbyn     ...       420.2496  151.90  77.3853       190.5759
# Dont know        ...         7.3728    0.00   0.0000         0.0000
#
#                Midlands / Wales    North  Scotland  Unnamed: 13  Unnamed: 14  \
# Owen Smith              66.3965   99.470   30.1252          NaN          NaN
# Jeremy Corbyn          109.4645  181.888   20.7760          NaN          NaN
# Dont know               3.5890    2.842    1.5582          NaN          NaN
#
#                Unnamed: 15
# Owen Smith             NaN
# Jeremy Corbyn          NaN
# Dont know             NaN
#
# [3 rows x 29 columns]

# %%
raw.loc[ft.index[2:4]]
# Out:
#                    Total  Jeremy Corbyn  Yvette Cooper  Andy Burnham  \
# I have voted      988.43         507.31         175.42        151.34
# I have not voted   30.57          15.69           3.58          9.66
#
#                   Liz Kendall  Did not vote  Pre 2015 GE  \
# I have voted            50.35          91.2        470.4
# I have not voted         2.65           3.8         19.6
#
#                   During 2015 Leadership Election  After JC Elected  Remain  \
# I have voted                               281.28            233.64  889.49
# I have not voted                            11.72              2.36   27.51
#
#                     ...      25-39   40-59     60+   ABC1    C2DE  London  \
# I have voted        ...     263.62  359.66  253.65  662.4  321.44  203.67
# I have not voted    ...       5.38    7.34   13.35   27.6    6.56   15.33
#
#                   Rest of South  Midlands / Wales   North  Scotland
# I have voted             289.06             174.6  265.58     49.98
# I have not voted           8.94               5.4    5.42      1.02
#
# [2 rows x 26 columns]

# %% [raw]
# What do we want to do?
# (0) Reconstruct approximate raw numbers
# - multiply % by % who voted by unweighted numbers
# - renormalise to known number of voters (has to be done by category)
#    - create sum for each category, divide through all elements of that category
# - round (and maybe renormalise?)??
# - technically, the *correct* solution is to work from from error ranges in the data ( i.e. [0.01 .99] reflects a rounding from [0.005 .995] to [0.015 .985] )
#
# (1) Get test statistics for likelihood that all groups within *are not* from the same distribution - e.g. reject the null
# - we have frequencies (not individual full data samples), so chi-squared is probably the right choice
#
# (2) Per group measure of significance (brute force ... group X vs all other groups in same category?)
#
# (3) Confidence interval of <true population> statistic (mean/proportion)
#
# (4) How to deal with demographic weightings?

# %%
# (0) Reconstruction

ft.loc[ ft.index[1]  ] # unweighted sample
ft.loc[ ft.index[2]  ] /100 # have voted
ft.loc[ ft.index[4:] ] /100 # Owen Smith/Jeremy Corbyn/Dont know
# maybe add this as a row?
ft.loc[ ft.index[1]  ] * (ft.loc[ ft.index[3]  ] /100) # did not vote in LE

raw =  ft.loc[ ft.index[1]  ] * (ft.loc[ ft.index[2]  ] /100) * (ft.loc[ ft.index[4:] ] /100)

# raw.sum(axis=0)
# raw
for cat in yougov_categories:
    raw[cat] = raw[cat]*986/raw[cat].sum().sum()
    print( raw[cat].sum().sum() )



#print( raw[yougov_categories[1]].sum().sum() )

raw[cat].sum().sum()
# Out:
# 986.0
# 986.0
# 986.0
# 986.0
# 986.0
# 986.0
# 986.0
# 986.0
# 986.0

# %%
raw
# Out:
#                   Total  Jeremy Corbyn  Yvette Cooper  Andy Burnham  \
# Owen Smith     405.2563      64.520233     147.062910    108.194032
# Jeremy Corbyn  583.1737     467.771688      16.523922     36.064677
# Dont know       9.8843       5.376686       3.304784      0.000000
#
#                Liz Kendall  Did not vote  Pre 2015 GE  \
# Owen Smith       42.299263     17.863525   297.370978
# Jeremy Corbyn     0.863250     74.274658   174.646447
# Dont know        0.000000      1.880371     4.720174
#
#                During 2015 Leadership Election  After JC Elected      Remain  \
# Owen Smith                           72.340756         33.756516  381.752779
# Jeremy Corbyn                       214.128638        186.786055  506.044382
# Dont know                            0.000000          2.250434    8.877972
#
#                   ...             ABC1        C2DE     London  Rest of South  \
# Owen Smith        ...       311.607517   91.220824  68.911297     129.743594
# Jeremy Corbyn     ...       422.895916  152.856516  77.708484     191.371801
# Dont know        ...         7.419227    0.000000   0.000000       0.000000
#
#                Midlands / Wales       North   Scotland  Unnamed: 13  \
# Owen Smith            66.673791   99.885416  30.251012          NaN
# Jeremy Corbyn        109.921656  182.647618  20.862767          NaN
# Dont know             3.603989    2.853869   1.564708          NaN
#
#                Unnamed: 14  Unnamed: 15
# Owen Smith             NaN          NaN
# Jeremy Corbyn          NaN          NaN
# Dont know             NaN          NaN
#
# [3 rows x 29 columns]

# %%
# Out:
# 490.94965000000002

# %%
raw
# Out:
#                   Total  Jeremy Corbyn  Yvette Cooper  Andy Burnham  \
# Owen Smith     405.2563      64.520233     147.062910    108.194032
# Jeremy Corbyn  583.1737     467.771688      16.523922     36.064677
# Dont know       9.8843       5.376686       3.304784      0.000000
#
#                Liz Kendall  Did not vote  Pre 2015 GE  \
# Owen Smith       42.299263     17.863525   297.370978
# Jeremy Corbyn     0.863250     74.274658   174.646447
# Dont know        0.000000      1.880371     4.720174
#
#                During 2015 Leadership Election  After JC Elected      Remain  \
# Owen Smith                           72.340756         33.756516  381.752779
# Jeremy Corbyn                       214.128638        186.786055  506.044382
# Dont know                            0.000000          2.250434    8.877972
#
#                   ...             ABC1        C2DE     London  Rest of South  \
# Owen Smith        ...       311.607517   91.220824  68.911297     129.743594
# Jeremy Corbyn     ...       422.895916  152.856516  77.708484     191.371801
# Dont know        ...         7.419227    0.000000   0.000000       0.000000
#
#                Midlands / Wales       North   Scotland  Unnamed: 13  \
# Owen Smith            66.673791   99.885416  30.251012          NaN
# Jeremy Corbyn        109.921656  182.647618  20.862767          NaN
# Dont know             3.603989    2.853869   1.564708          NaN
#
#                Unnamed: 14  Unnamed: 15
# Owen Smith             NaN          NaN
# Jeremy Corbyn          NaN          NaN
# Dont know             NaN          NaN
#
# [3 rows x 29 columns]

# %%
# function takes a (part of a) DataFrame
# which has real numbers, but which sums to an integer
# finds the (integer) difference between that sum and the sum of the integer parts of all values
# assign those individuals
# deterministic option - assign by descending order of remainder size (can't have more assignees than remainders over 0)
# stochastic option    - assign by chance depending on proportion of all fractions




to_be_assigned = 986 - np.floor(raw[cat]).sum().sum()
int_raw = np.floor(raw[cat]).astype('int')
remainders = raw[cat] - int_raw
remainders.values.flatten().sort()
# sort on values, return indices, take top X indices by size, use to increment int_raw

# %%
remainders.loc[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-22bb38572104> in <module>()
# ----> 1 remainders.loc[2]
#
# C:\Users\Marios\Anaconda3\envs\yougov\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1309             return self._getitem_tuple(key)
#    1310         else:
# -> 1311             return self._getitem_axis(key, axis=0)
#    1312
#    1313     def _getitem_axis(self, key, axis=0):
#
# C:\Users\Marios\Anaconda3\envs\yougov\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1479
#    1480         # fall thru to straight lookup
# -> 1481         self._has_valid_type(key, axis)
#    1482         return self._get_label(key, axis=axis)
#    1483
#
# C:\Users\Marios\Anaconda3\envs\yougov\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1406
#    1407             try:
# -> 1408                 key = self._convert_scalar_indexer(key, axis)
#    1409                 if key not in ax:
#    1410                     error()
#
# C:\Users\Marios\Anaconda3\envs\yougov\lib\site-packages\pandas\core\indexing.py in _convert_scalar_indexer(self, key, axis)
#     193         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     194         # a scalar
# --> 195         return ax._convert_scalar_indexer(key, kind=self.name)
#     196
#     197     def _convert_slice_indexer(self, key, axis):
#
# C:\Users\Marios\Anaconda3\envs\yougov\lib\site-packages\pandas\indexes\base.py in _convert_scalar_indexer(self, key, kind)
#    1139             elif kind in ['loc'] and is_integer(key):
#    1140                 if not self.holds_integer():
# -> 1141                     return self._invalid_indexer('label', key)
#    1142
#    1143         return key
#
# C:\Users\Marios\Anaconda3\envs\yougov\lib\site-packages\pandas\indexes\base.py in _invalid_indexer(self, form, key)
#    1252                         "indexers [{key}] of {kind}".format(
#    1253                             form=form, klass=type(self), key=key,
# -> 1254                             kind=type(key)))
#    1255
#    1256     def get_duplicates(self):
#
# TypeError: cannot do label indexing on <class 'pandas.indexes.base.Index'> with these indexers [2] of <class 'int'>
